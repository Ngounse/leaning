# %%
#1D array ( pandas series )
#2D array ( pandas dataframe )
#3D array ( pandas panel )

# %%
import pandas as pd

# %%
df = pd.read_table('https://github.com/sophalITC/datasci/raw/master/employee.tsv')

# %%
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children
# 0      M  31-Jul-89       nurse       2.2  223700.0       True         1
# 1    NaN  30-Oct-92     dentist       6.7  121100.0       True         1
# 2      F        NaN  accountant       9.0       NaN      False         2
# 3      F  17-Sep-87    engineer       1.7   79900.0      False         0
# 4      M  24-Jan-93     teacher       3.6   32800.0      False         2
# 5      F        NaN   developer       1.8       NaN       True         1
# 6      F  26-Sep-94       nurse       5.6  272500.0      False         1
# 7      M   7-May-91      lawyer       4.1   41600.0      False         0
# 8      M   4-Dec-94     teacher       3.3  141300.0       True         0
# 9      M  10-Jul-87      police       6.5   68000.0       True         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gender      9 non-null      object
#  1   dob         8 non-null      object
#  2   occupation  10 non-null     object
#  3   work_exp    10 non-null     float64
#  4   salary      8 non-null      float64
#  5   own_house   10 non-null     bool
#  6   children    10 non-null     int64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 618.0+ bytes

# %% [markdown]
# ### convert date

# %%
df = pd.read_table('https://github.com/sophalITC/datasci/raw/master/employee.tsv', parse_dates=['dob'])
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children
# 0      M 1989-07-31       nurse       2.2  223700.0       True         1
# 1    NaN 1992-10-30     dentist       6.7  121100.0       True         1
# 2      F        NaT  accountant       9.0       NaN      False         2
# 3      F 1987-09-17    engineer       1.7   79900.0      False         0
# 4      M 1993-01-24     teacher       3.6   32800.0      False         2
# 5      F        NaT   developer       1.8       NaN       True         1
# 6      F 1994-09-26       nurse       5.6  272500.0      False         1
# 7      M 1991-05-07      lawyer       4.1   41600.0      False         0
# 8      M 1994-12-04     teacher       3.3  141300.0       True         0
# 9      M 1987-07-10      police       6.5   68000.0       True         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gender      9 non-null      object
#  1   dob         8 non-null      datetime64[ns]
#  2   occupation  10 non-null     object
#  3   work_exp    10 non-null     float64
#  4   salary      8 non-null      float64
#  5   own_house   10 non-null     bool
#  6   children    10 non-null     int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 618.0+ bytes

# %%
df.salary.mean()
# Out:
# 122612.5

# %%
df.salary.median()
# Out:
# 100500.0

# %%
### mode high freequenty
df.children.mode()
# Out:
# 0    1
# dtype: int64

# %%
df.occupation.value_counts()
# Out:
# nurse         2
# teacher       2
# dentist       1
# accountant    1
# engineer      1
# developer     1
# lawyer        1
# police        1
# Name: occupation, dtype: int64

# %%
df.occupation.str.upper()
# Out:
# 0         NURSE
# 1       DENTIST
# 2    ACCOUNTANT
# 3      ENGINEER
# 4       TEACHER
# 5     DEVELOPER
# 6         NURSE
# 7        LAWYER
# 8       TEACHER
# 9        POLICE
# Name: occupation, dtype: object

# %%
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children
# 0      M 1989-07-31       nurse       2.2  223700.0       True         1
# 1    NaN 1992-10-30     dentist       6.7  121100.0       True         1
# 2      F        NaT  accountant       9.0       NaN      False         2
# 3      F 1987-09-17    engineer       1.7   79900.0      False         0
# 4      M 1993-01-24     teacher       3.6   32800.0      False         2
# 5      F        NaT   developer       1.8       NaN       True         1
# 6      F 1994-09-26       nurse       5.6  272500.0      False         1
# 7      M 1991-05-07      lawyer       4.1   41600.0      False         0
# 8      M 1994-12-04     teacher       3.3  141300.0       True         0
# 9      M 1987-07-10      police       6.5   68000.0       True         1

# %%
pd.to_datetime('today').year
# Out:
# 2022

# %%
df.dob
# Out:
# 0   1989-07-31
# 1   1992-10-30
# 2          NaT
# 3   1987-09-17
# 4   1993-01-24
# 5          NaT
# 6   1994-09-26
# 7   1991-05-07
# 8   1994-12-04
# 9   1987-07-10
# Name: dob, dtype: datetime64[ns]

# %%
df['age'] = pd.to_datetime('today').year - df.dob.dt.year

# %%
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children   age
# 0      M 1989-07-31       nurse       2.2  223700.0       True         1  33.0
# 1    NaN 1992-10-30     dentist       6.7  121100.0       True         1  30.0
# 2      F        NaT  accountant       9.0       NaN      False         2   NaN
# 3      F 1987-09-17    engineer       1.7   79900.0      False         0  35.0
# 4      M 1993-01-24     teacher       3.6   32800.0      False         2  29.0
# 5      F        NaT   developer       1.8       NaN       True         1   NaN
# 6      F 1994-09-26       nurse       5.6  272500.0      False         1  28.0
# 7      M 1991-05-07      lawyer       4.1   41600.0      False         0  31.0
# 8      M 1994-12-04     teacher       3.3  141300.0       True         0  28.0
# 9      M 1987-07-10      police       6.5   68000.0       True         1  35.0

# %%
df.age.mean()
# Out:
# 31.125

# %%
df.describe()
# Out:
#         work_exp         salary   children        age
# count  10.000000       8.000000  10.000000   8.000000
# mean    4.450000  122612.500000   0.900000  31.125000
# std     2.429106   86579.978509   0.737865   2.900123
# min     1.700000   32800.000000   0.000000  28.000000
# 25%     2.475000   61400.000000   0.250000  28.750000
# 50%     3.850000  100500.000000   1.000000  30.500000
# 75%     6.275000  161900.000000   1.000000  33.500000
# max     9.000000  272500.000000   2.000000  35.000000

# %%
df.dob.dt.day_name()
# Out:
# 0      Monday
# 1      Friday
# 2         NaN
# 3    Thursday
# 4      Sunday
# 5         NaN
# 6      Monday
# 7     Tuesday
# 8      Sunday
# 9      Friday
# Name: dob, dtype: object

# %% [markdown]
# # pandas series ( 1D array )

# %%
payment = pd.Series([150, 200, 80, 90, 120, 99, 145])
payment
# Out:
# 0    150
# 1    200
# 2     90
# 3    120
# 4     99
# 5    145
# dtype: int64

# %%
payment[1]
# Out:
# 200

# %%
payment[-3:]
# Out:
# 3    120
# 4     99
# 5    145
# dtype: int64

# %%
s = pd.Series([150, 200, 80, 90, 120, 99, 145], index=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul'])
s
# Out:
# Jan    150
# Feb    200
# Mar     80
# Apr     90
# May    120
# Jun     99
# Jul    145
# dtype: int64

# %%
s['Apr']
# Out:
# 90

# %%
# %matplotlib inline

# %%
s.plot();

# %%
s.plot(kind='bar');

# %%
s.plot(kind='barh');

# %% [markdown]
# # Pandas Dataframe ( array 2D )

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sophalITC/datasci/master/mpg.csv')

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
df.sample(5)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 175       toyota          4runner 4wd    3.4  1999    6    auto(l4)   4   15
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 210   volkswagen                  gti    2.0  2008    4    auto(s6)   f   22
# 154      pontiac           grand prix    3.1  1999    6    auto(l4)   f   18
# 101        honda                civic    1.6  1999    4  manual(m5)   f   25
#
#      hwy fl       class
# 175   19  r         suv
# 69    12  e      pickup
# 210   29  p     compact
# 154   26  r     midsize
# 101   32  r  subcompact

# %%
mileToKilo = 0.425144
df['cty_kml'] = df['cty'] * mileToKilo
df['hwy_kml'] = df['hwy'] * mileToKilo

# %%
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#     cty_kml    hwy_kml
# 0  7.652592  12.329176
# 1  8.928024  12.329176
# 2  8.502880  13.179464
# 3  8.928024  12.754320
# 4  6.802304  11.053744

# %%
# str(round(, 2))
df['cty_kml'] = df['cty_kml'].round(2)
df['hwy_kml'] = df['hwy_kml'].round(2)

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  cty_kml  hwy_kml
# 0    compact     7.65    12.33
# 1    compact     8.93    12.33
# ...

# %%
df['trans_1'] = df['trans'].str[0]

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  cty_kml  hwy_kml trans_1
# 0    compact     7.65    12.33       a
# ...

# %%
df.shape
# Out:
# (234, 14)

# %%
df.mean()
# Out:
# /tmp/ipykernel_8078/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# displ         3.471795
# year       2003.500000
# cyl           5.888889
# cty          16.858974
# hwy          23.440171
# cty_kml       7.167991
# hwy_kml       9.964957
# dtype: float64

# %%
df['manufacturer'].value_counts()
# Out:
# dodge         37
# toyota        34
# volkswagen    27
# ford          25
# chevrolet     19
# audi          18
# hyundai       14
# subaru        14
# nissan        13
# honda          9
# jeep           8
# pontiac        5
# land rover     4
# mercury        4
# lincoln        3
# Name: manufacturer, dtype: int64

# %%
n = df.describe()
n
# Out:
#             displ         year         cyl         cty         hwy  \
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000
#
#           cty_kml     hwy_kml
# count  234.000000  234.000000
# mean     7.167991    9.964957
# std      1.808473    2.531102
# min      3.830000    5.100000
# 25%      5.950000    7.650000
# 50%      7.230000   10.200000
# 75%      8.080000   11.480000
# max     14.880000   18.710000

# %%
t = df.describe().T
t
# Out:
#          count         mean       std      min      25%      50%      75%  \
# displ    234.0     3.471795  1.291959     1.60     2.40     3.30     4.60
# year     234.0  2003.500000  4.509646  1999.00  1999.00  2003.50  2008.00
# cyl      234.0     5.888889  1.611534     4.00     4.00     6.00     8.00
# cty      234.0    16.858974  4.255946     9.00    14.00    17.00    19.00
# hwy      234.0    23.440171  5.954643    12.00    18.00    24.00    27.00
# cty_kml  234.0     7.167991  1.808473     3.83     5.95     7.23     8.08
# hwy_kml  234.0     9.964957  2.531102     5.10     7.65    10.20    11.48
#
#              max
# displ       7.00
# year     2008.00
# cyl         8.00
# cty        35.00
# hwy        44.00
# cty_kml    14.88
# hwy_kml    18.71

# %%
n.plot()
# Out:
# <AxesSubplot:>

# %%
c = df.corr()

# %%
c.plot()
# Out:
# <AxesSubplot:>

# %%
df.nlargest(10, columns='cty')
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
# 99         honda       civic    1.6  1999    4  manual(m5)   f   28   33  r
# 196       toyota     corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 104        honda       civic    1.8  2008    4  manual(m5)   f   26   34  r
# 195       toyota     corolla    1.8  1999    4  manual(m5)   f   26   35  r
# 197       toyota     corolla    1.8  2008    4    auto(l4)   f   26   35  r
# 101        honda       civic    1.6  1999    4  manual(m5)   f   25   32  r
# 105        honda       civic    1.8  2008    4    auto(l5)   f   25   36  r
#
#           class  cty_kml  hwy_kml trans_1
# 221  subcompact    14.88    18.71       m
# 212     compact    14.03    18.71       m
# ...

# %%
df.nsmallest(10, columns='cty')
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 54         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 59         dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 65         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 126         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
# 19     chevrolet   c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   11
# 29     chevrolet      k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4   11
# 30     chevrolet      k1500 tahoe 4wd    5.7  1999    8    auto(l4)   4   11
# 43         dodge          caravan 2wd    3.3  2008    6    auto(l4)   f   11
# 55         dodge    dakota pickup 4wd    5.2  1999    8  manual(m5)   4   11
#
#      hwy fl    class  cty_kml  hwy_kml trans_1
# 54    12  e   pickup     3.83     5.10       a
# ...

# %%
import pandas as pd
df = pd.read_csv('https://github.com/sophalITC/datasci/raw/master/list_of_provinces_of_cambodiaV2.csv')
df
# Out:
#     SNo                       Name        Capital (Seat)  \
# 0     1    Phnom Penh Municipality            Phnom Penh
# 1     2  Banteay Meanchey Province        Serei Saophoan
# 2     3        Battambang Province            Battambang
# 3     4      Kampong Cham Province          Kampong Cham
# 4     5   Kampong Chhnang Province        Kampong Chhang
# 5     6      Kampong Speu Province          Kampong Speu
# 6     7      Kampong Thom Province          Kampong Thom
# 7     8            Kampot Province                Kampot
# 8     9            Kandal Province              Ta Khmao
# 9    10          Koh Kong Province              Koh Kong
# 10   11               Kep Province                   Kep
# 11   12            Kratie Province                Kratie
# 12   13        Mondulkiri Province            Senmonorom
# 13   14    Oddar Meanchey Province              Samraong
# 14   15            Pailin Province                Pailin
# ...

# %%
pd.concat([df.head(), df.tail()])
# Out:
#     SNo                       Name  Capital (Seat) Population (2008 census)  \
# 0     1    Phnom Penh Municipality      Phnom Penh                15,01,725
# 1     2  Banteay Meanchey Province  Serei Saophoan                 6,77,872
# 2     3        Battambang Province      Battambang                10,58,174
# 3     4      Kampong Cham Province    Kampong Cham                 9,28,694
# 4     5   Kampong Chhnang Province  Kampong Chhang                 4,72,341
# 20   21         Siem Reap Province       Siem Reap                 8,96,443
# 21   22       Stung Treng Province     Stung Treng                 1,11,671
# 22   23        Svay Rieng Province      Svay Rieng                 4,82,788
# 23   24             Takeo Province        Daun Keo                 8,44,906
# 24   25       Tbong Khmum Province           Soung                 7,54,000
#
#    Area (square_km) Density    ISO
# 0            678.46   2,200  KH-12
# 1             6,679     102   KH-1
# ...

# %%
#histrogram
#
